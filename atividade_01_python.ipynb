# %% [markdown]
# <a href="https://colab.research.google.com/github/ds5286556-source/atividades-python/blob/main/atividade_01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 01 - Introdução ao Python

# %%
print("Olá,mundo!")
print("Curso tecnico em Informática")
# Out:
# Olá,mundo!
# Curso tecnico em Informática

# %%
disciplina = input("Digite o nome da disciplina: ")
conteudo = input("Digite o nome do conteudo estudado: ")
atividade = input("DIgte o numero da atividade: ")
print = ("\n--- Informações da atividade ---")
print = ("Disciplina:,disciplina")
print = ("Conteudo:,conteudo")
print = ("Atidade:, atividade")
# Out:
# Digite o nome da disciplina: ICST
# Digite o nome do conteudo estudado: DADOS
# DIgte o numero da atividade: 01

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado:",soma)
# Out:
# Resultado: 30
